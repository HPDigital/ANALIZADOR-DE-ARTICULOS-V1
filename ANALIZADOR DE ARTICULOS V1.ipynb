# %%
from openai import OpenAI
import fitz  # PyMuPDF
# Configuración de la clave de la API de OpenAI

client = OpenAI(api_key="YOUR_API_KEY_HERE")


# Función para leer el contenido del archivo
def extraer_texto_pdf(ruta_pdf):
    # Abrir el documento PDF
    documento = fitz.open(ruta_pdf)
    
    # Recopilar el texto de cada página
    texto_completo = ""
    for pagina in documento:
        texto_completo += pagina.get_text()
    
    # Cerrar el documento
    documento.close()
    return texto_completo


# Función para interactuar con ChatGPT y obtener el análisis del documento
def analizar_documento(contenido):
    response = client.chat.completions.create(
        model="gpt-4-turbo",  # Utiliza el modelo más reciente disponible
        messages=[
            {"role": "system", "content": "Eres un experto en redaccion de articulos cientificos y estas asistiendo con un análisis de un documento científico."},
            {"role": "user", "content": f"Hola, ¿podrías ayudarme con el análisis de este artículo científico que adjunto? Necesito lo siguiente: y el articulo en cuation es. {contenido}"},
            {"role": "user", "content": f"""Citación en formato APA versión 7: Por favor, proporciona la citación completa del artículo según las normas APA versión 7.
            \n\nResumen del artículo: Elabora un resumen conciso del contenido del artículo, destacando los puntos clave y los hallazgos principales.
            \n\nObjetivo del artículo: Indica cuál es el objetivo principal del estudio que se discute en el artículo.
            \n\nMetodología utilizada: Indica cual es la metodología que el autor indica que se usa para esta investigación.
            \n\nLectura preliminar:Elabora un informe de la Lectura preliminar para evaluar pertinencia.
            \n\nAnálisi detallado:Elabora un informe del análisis detallado de cada sección del artículo.
            \n\nInform de evaluación:Elabora un informe de la evaluación crítica de métodos y resultados.
            \n\nSintesisi de información:Elabora una síntesis de información encontrada.
            \n\nContextualización:Elabora la contextualización en la literatura existente.
            \n\nReflexion:Elabora la reflexión sobre implicaciones y futuras direcciones.
            \n\nRedaccion: Elabora la redacción del manuscrito de revisión.
            \n\nRevision:Elabora un inform sebre la revisión y edición del manuscrito.
            \n\nFeedbak:Elabora un informaosbre los Feedback de colegas. 
            \n\n{contenido}"""},              
        ],
        #max_tokens=30048
    )
    return response.choices[0].message.content

# Ruta del archivo local (ajustar según sea necesario)
ruta_archivo = r"C:\Users\HP\Downloads\documento.pdf"

# Leer el contenido del documento
contenido = extraer_texto_pdf(ruta_archivo)

# Obtener el análisis del documento
analisis = analizar_documento(contenido)

# Imprimir el análisis
print(analisis)
# Out:
# **Citación en formato APA versión 7:**
#
# Abrahamsson, S. (2024). Smartphone bans, student outcomes and mental health. *Institutt for samfunnsøkonomi, Department of Economics, SAM 01/24*, Norwegian Institute of Public Health. https://www.nhh.no
#
# ---
#
# **Resumen del artículo:**
#
# El artículo examina cómo la prohibición de los teléfonos inteligentes en las escuelas intermedias noruegas afecta el bienestar y el aprendizaje de los estudiantes. A través de un diseño de estudio de eventos y combinando datos administrativos detallados con datos de encuestas sobre las políticas de teléfonos inteligentes de las escuelas, el estudio encuentra que la prohibición está asociada con una disminución significativa en la asistencia sanitaria por síntomas psicológicos y enfermedades entre las niñas, así como una reducción en el acoso escolar en ambos sexos. Además, se observa una mejora en el rendimiento académico de las niñas, evidenciado por aumentos en el promedio de calificaciones (GPA) y la probabilidad de seguir una trayectoria académica en la secundaria. Estos efectos son especialmente pronunciados en niñas de entornos socioeconómicos bajos.
#
# ---
#
# **Objetivo del artículo:**
#
# El objetivo principal del estudio es investigar los efectos de prohibir los smartphones en las escuelas sobre la salud mental, los resultados educativos y la incidencia de acoso entre los estudiantes de secundaria en Noruega.
#
# ---
#
# **Metodología utilizada:**
#
# El estudio emplea un diseño de estudio de eventos no paramétrico para evaluar los efectos temporales de la implementación de la prohibición de smartphones en diferentes escuelas. Se analizan datos combinados de registros administrativos noruegos, una encuesta a nivel escolar sobre políticas de smartphones y datos de salud de los estudiantes.
#
# ---
#
# **Lectura preliminar (Evaluación de pertinencia):**
#
# La investigación es extremadamente relevante dado el creciente uso de smartphones entre adolescentes y la preocupación contemporánea sobre sus efectos en la salud mental y el rendimiento académico. Al centrarse en una intervención política concreta y emplear un riguroso diseño metodológico, el estudio ofrece insights valiosos que están directamente alineados con las necesidades de formuladores de políticas, educadores y padres.
#
# ---
#
# **Análisis detallado de cada sección del artículo:**
#
# 1. **Introducción**: Establece un contexto sólido sobre la prevalencia del uso de smartphones y su impacto percibido en los jóvenes, justificando la necesidad del estudio.
# 2. **Métodos**: Descripción detallada de la metodología de estudio de eventos, la selección de datos y el análisis estadístico empleado.
# 3. **Resultados**: Presenta hallazgos claros y específicos sobre los impactos en salud mental, rendimiento académico y acoso, diferenciando efectos por género y estatus socioeconómico.
# 4. **Discusión**: Integra los resultados con la literatura existente, discutiendo las implicaciones de los hallazgos y cómo estos informan políticas y prácticas educativas futuras.
# 5. **Conclusiones**: Resume los hallazgos principales y sugiere direcciones futuras para la investigación y la política educativa.
#
# ---
#
# **Informe de evaluación crítica de métodos y resultados:**
#
# La metodología del estudio es robusta, aprovechando la variación en la implementación de las políticas de prohibición de smartphones para aislar los efectos causales. Los resultados son presentados con claridad y están bien respaldados por los análisis. Sin embargo, la generalización de los resultados podría estar limitada por el contexto específico de Noruega.
#
# ---
#
# **Síntesis de información encontrada y contextualización en la literatura existente:**
#
# El estudio contribuye significativamente a la literatura sobre tecnología en la educación y la salud mental estudiantil, proporcionando evidencia empírica robusta de los beneficios de las políticas de restricción de smartphones en el contexto escolar. Está bien alineado con investigaciones previas que sugieren impactos negativos del tiempo de pantalla en los jóvenes, pero va más allá al ofrecer una evaluación basada en políticas reales de intervención.
#
# ---
#
# **Reflexión sobre implicaciones y futuras direcciones:**
#
# Los hallazgos impulsan un respaldo más fuerte para políticas educativas que regulen el uso de smartphones en las escuelas como una medida para mejorar la salud mental y los resultados educativos. Futuras investigaciones podrían explorar los efectos a largo plazo de estas políticas y su implementación en diferentes contextos culturales y educativos.
#
# ---
#
# **Redacción del manuscrito de revisión y revisión del manuscrito:**
#
# El manuscrito de revisión debe enfocarse en contextualizar los hallazgos dentro de las tendencias globales en educación y tecnología, argumentando para balancear el uso de tecnología con consideraciones de bienestar estudiantil. La revisión debería asegurar que la discusión sea accesible para un público amplio, incluyendo formuladores de políticas, educadores y académicos.
#
# ---
#
# **Feedback de colegas:**
#
# Antes de la publicación final, sería prudente obtener retroalimentación de otros expertos en psicología educativa y políticas públicas para refinar aún más el análisis y asegurar que las interpretaciones y recomendaciones sean sólidas y relevantes.
